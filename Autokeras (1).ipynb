# %%
# !pip install autokeras
import tensorflow as tf
from tensorflow import keras
# !pip install git+https://github.com/keras-team/keras-tuner.git@1.0.2rc2
# Out:
# ...
#   Cloning https://github.com/keras-team/keras-tuner.git (to revision 1.0.2rc2) to /tmp/pip-req-build-36w91kma
#   Running command git clone -q https://github.com/keras-team/keras-tuner.git /tmp/pip-req-build-36w91kma
#   Running command git checkout -q 8f0d4550417af1676143499c688434065eb807c9
# ...
#   Created wheel for keras-tuner: filename=keras_tuner-1.0.2rc2-cp36-none-any.whl size=91717 sha256=5b504a73345015f28d3a951fc9ff8ac99a46f6180791a0da73f652269cb01e20
#   Stored in directory: /tmp/pip-ephem-wheel-cache-uoree2ux/wheels/3b/a3/4d/85f2944f8fc55e8bb9fc23a1470ef9dfcb170de55958ba2d53
# Successfully built keras-tuner

# %%
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
import autokeras as ak
from autokeras import ImageClassifier

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
x_train.shape[0], x_test.shape[0], y_train.shape[0], y_test.shape[0]
# Out:
# (60000, 10000, 60000, 10000)

# %%
clf = ak.ImageClassifier(
    overwrite=True,
    max_trials=5)

# %%
history = clf.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test))

# %%
_,acc= clf.evaluate(x_test, y_test)
print("Best Test Accuracy: ", acc*100)
# Out:
# 313/313 [==============================] - 30s 96ms/step - loss: 0.2467 - accuracy: 0.9376
# Best Test Accuracy:  93.76000165939331

# %%
model = clf.export_model()

# %%
tf.keras.utils.plot_model(model, show_shapes= True, show_layer_names= True)
